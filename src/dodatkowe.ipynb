# %% [markdown]
# # Zadanie dodatkowe
# Za pomoca jednej z poznanych metod zaimplementuj generator liczb losowych z rozkładu Poissona

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def generuj(lam, size):
    zmienne = np.zeros(size)
    for s in range(size):
        n = 1
        a = 1
        while True:
            U = np.random.uniform(0, 1)
            a *= U
            if a >= np.exp(-lam):
                n += 1
            else:
                zmienne[s] = n - 1
                break
    return zmienne

# %%
lam, size = 1, 100
X = generuj(lam, size)
sns.kdeplot(X, label="Rozkład wygenerowanych zmiennych", color="green")
sns.kdeplot(np.random.poisson(lam=lam, size=size), label="Rozkład Poissona", color="red")
plt.title("Porównanie rozkładów")
plt.legend()
plt.show()
# Out:
# C:\Users\ameli\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ameli\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
